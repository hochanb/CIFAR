# %%
from visualize import draw_accuracy


baseline = [63, 77, 80]
false_10 = [59, 71, 71]
false_20 = [53, 67, 60]
perturbation = [52, 63, 73]
shuffle = [10, 9, 9]

draw_accuracy(
    baseline,
    false_10,
    false_20,
    perturbation,
    shuffle,
)
